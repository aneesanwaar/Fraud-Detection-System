# %% [markdown]
# **1. Data Preprocessing:**

# %% [markdown]
# Loading Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the dataset
df = pd.read_csv("/content/creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#checking for missing values
print(df.isnull().sum())
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# removing all rows with missing values to avoid introducing bias
df = df.dropna()

# %%
#checking again for missing values
print(df.isnull().sum())
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#checking the class distribution
print(df["Class"].value_counts())
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# So this Dataset is highly unblanced

# %% [markdown]
# Applying random undersampling to the majority class (Class = 0) to match the minority class (Class = 1):

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
# defining undersampling strategy
undersampler = RandomUnderSampler(random_state=42)

# %%
# spliting features (X) and target (y)
X = df.drop(columns=['Class'])
y = df['Class']

# %%
# applying undersampling
X_resampled, y_resampled = undersampler.fit_resample(X, y)

# %%
# checking new class distribution
print(pd.Series(y_resampled).value_counts())
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %% [markdown]
# Spliting data into Training and Testing sets

# %%
from sklearn.model_selection import train_test_split

# %%
# splitting the balanced dataset into training (80%) and testing (20%) sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled)

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()

# Fit on the training data and transform both train and test sets
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# **2. Model Training:**

# %% [markdown]
# Training a Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
# Initializing Random Forest
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
#training random forest
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Making predictions
y_pred = rf_model.predict(X_test)

# %% [markdown]
# **3. Model Evaluation:**

# %% [markdown]
# Evaluating the system's precision, recall, and F1-score.

# %%
# evaluation metrics
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96        99
#            1       0.97      0.94      0.95        98
#
#     accuracy                           0.95       197
#    macro avg       0.95      0.95      0.95       197
# weighted avg       0.95      0.95      0.95       197

# %% [markdown]
# **4. Testing Interface:**

# %%
import numpy as np
import pandas as pd

def predict_transaction(model, scaler, X_test):
    """
    Function to test fraud detection using command-line input.
    Allows manual input or selection of a random sample transaction.
    """
    print("\n🔹 Choose Input Method:")
    print("1. Manually enter transaction details")
    print("2. Use a sample transaction from the dataset")

    choice = input("Enter choice (1 or 2): ").strip()

    if choice == "1":
        # Manually enter transaction details
        print("\nEnter transaction details:")
        input_data = []
        for i in range(X_test.shape[1]):  # Loop through all features
            value = float(input(f"Feature {i + 1}: "))  # Get user input
            input_data.append(value)
        input_data = np.array(input_data).reshape(1, -1)  # Reshape for prediction

    elif choice == "2":
        # Convert X_test to DataFrame with feature names
        feature_names = X_resampled.columns  # Get feature names from the original dataset
        X_test_df = pd.DataFrame(X_test, columns=feature_names)

        # Select a random sample transaction
        input_data = X_test_df.sample(1)  # Keep as DataFrame to retain feature names
        print("\n Using sample transaction from dataset:\n", input_data)

        # Make a prediction
        prediction = model.predict(input_data)[0]

        # Display the result
        if prediction == 1:
            print("\n Fraudulent Transaction Detected!")
        else:
            print("\n Legitimate Transaction.")

# %%
predict_transaction(model, scaler, X_test)
# Out:
# 🔹 Choose Input Method:
# 1. Manually enter transaction details
# 2. Use a sample transaction from the dataset
# Enter choice (1 or 2): 2
#
# 🔹 Using sample transaction from dataset:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0  1.216533  0.414466  0.635686 -0.447715  1.538231  0.494954 -1.083503
#
#          V7        V8        V9  ...       V20       V21       V22       V23  \
# 0  0.165845  0.093174 -1.083684  ...  0.293549  0.023223 -0.405038  0.024287
#
#        V24       V25       V26       V27       V28    Amount
# 0 -0.58195 -0.789403  0.943659  0.481386  0.552056 -0.443484
#
# [1 rows x 30 columns]
#
# 🚨 Fraudulent Transaction Detected!
